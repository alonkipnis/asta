# %%
install.packages("devtools")     # only need to do this once
devtools::install_github("nickpoison/astsa")
# Out:
# also installing the dependencies ‘ps’, ‘later’, ‘fs’, ‘gh’, ‘rematch2’, ‘processx’, ‘fansi’, ‘rex’, ‘htmlwidgets’, ‘crosstalk’, ‘promises’, ‘purrr’, ‘usethis’, ‘callr’, ‘cli’, ‘covr’, ‘DT’, ‘ellipsis’, ‘httr’, ‘jsonlite’, ‘pkgbuild’, ‘rcmdcheck’, ‘remotes’, ‘rlang’, ‘roxygen2’, ‘rstudioapi’, ‘rversions’, ‘testthat’
#   There are binary versions available but the source versions are later:
#           binary  source needs_compilation
# ps         1.3.2   1.3.4              TRUE
# later      1.0.0 1.1.0.1              TRUE
# fs         1.3.2   1.5.0              TRUE
# rematch2   2.1.0   2.1.2             FALSE
# processx   3.4.2   3.4.4              TRUE
# rex        1.1.2   1.2.0             FALSE
# promises   1.1.0   1.1.1              TRUE
# purrr      0.3.3   0.3.4              TRUE
# usethis    1.5.1   1.6.1             FALSE
# callr      3.4.2   3.4.3             FALSE
# DT          0.12    0.15             FALSE
# ellipsis   0.3.0   0.3.1              TRUE
# httr       1.4.1   1.4.2             FALSE
# jsonlite   1.6.1   1.7.0              TRUE
# pkgbuild   1.0.6   1.1.0             FALSE
# remotes    2.1.1   2.2.0             FALSE
# rlang      0.4.5   0.4.7              TRUE
# roxygen2   7.1.0   7.1.1              TRUE
# rversions  2.0.1   2.0.2             FALSE
# devtools   2.2.2   2.3.1             FALSE
#
#
# The downloaded binary packages are in
# 	/var/folders/3n/c1thdb3136qc3c_4t5br9r6c0000gq/T//RtmpgQVhd2/downloaded_packages
# installing the source packages ‘ps’, ‘later’, ‘fs’, ‘rematch2’, ‘processx’, ‘rex’, ‘promises’, ‘purrr’, ‘usethis’, ‘callr’, ‘DT’, ‘ellipsis’, ‘httr’, ‘jsonlite’, ‘pkgbuild’, ‘remotes’, ‘rlang’, ‘roxygen2’, ‘rversions’, ‘devtools’
#
# Downloading GitHub repo nickpoison/astsa@HEAD
# ✔  checking for file ‘/private/var/folders/3n/c1thdb3136qc3c_4t5br9r6c0000gq/T/RtmpgQVhd2/remotesf37853922850/nickpoison-astsa-92ce01c/DESCRIPTION’ ...
# ─  preparing ‘astsa’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  looking to see if a ‘data/datalist’ file should be added
# ─  building ‘astsa_1.10.1.tar.gz’

# %%
library(astsa)

# %% [markdown]
# ## Chapter 1

# %% [markdown]
# #### Example 1.1

# %%
tsplot(jj, type="o", ylab="Quarterly Earnings per Share")
# Out:
# plot without title

# %% [markdown]
# #### Example 1.2

# %%
tsplot(globtemp, type="o", ylab="Global Temperature Deviations")
# Out:
# plot without title

# %% [markdown]
# #### Example 1.4

# %%
install.packages("xts")
# Out:
# The downloaded binary packages are in
# 	/var/folders/3n/c1thdb3136qc3c_4t5br9r6c0000gq/T//RtmpgQVhd2/downloaded_packages

# %%
library(xts)                              # this must be here
djiar = diff(log(djia$Close))[-1]         # approximate returns
plot(djiar, main="DJIA Returns", type="n")  
lines(djiar)
# Out:
# Warning message:
# “package ‘xts’ was built under R version 3.5.2”Loading required package: zoo
# Warning message:
# “package ‘zoo’ was built under R version 3.5.2”
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
# plot without title
# plot without title
